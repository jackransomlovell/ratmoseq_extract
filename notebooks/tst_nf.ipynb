# %%
import h5py
import matplotlib.pyplot as plt

# %%
# h5 = '/n/groups/datta/jlove/data/rat_seq/data_managment/habitat/fmr1/14weeks/session_20240722113743/proc/results_00.h5'
h5 = '/n/groups/datta/jlove/data/rat_seq/data_managment/habitat/fmr1/14weeks/session_20240722112532/proc/results_00.h5'

# %%
with h5py.File(h5, 'r') as f:
    print(f.keys())
    print(f['size_norm_v1'].shape)
    plt.figure()
    plt.imshow(f['size_norm_v1'][0])
    plt.figure()
    plt.imshow(f['frames'][0])
# Out:
# <KeysViewHDF5 ['frames', 'frames_mask', 'metadata', 'scalars', 'size_norm_v1', 'timestamps']>
# (14392, 176, 176)

# %%
import deeplabcut as dlc
# Out:
# Loading DLC 3.0.0rc6...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
# create video using deeplabcut
csv = '/n/groups/datta/jlove/data/rat_seq/data_managment/habitat/fmr1/14weeks/session_20240722111343/'
